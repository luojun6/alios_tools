# %%
import os
from explore_yuntool_logs import *
# Out:
# /home/lawjune/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/lawjune/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
log_path = os.path.join(current_dir, r"logs/srv_3dmodel_error")

# %%
extract_zst_files(log_path, "logcat")
extract_zst_files(log_path, "kernel")
all_log = merge_log_csv_files(log_path)
# Out:
# Found 59 txt.zst files.
# Extracting 20231213_080944_057_33_aplogcat.txt.zst with completion 1/59.
# Extracting 20231213_084941_926_54_aplogcat.txt.zst with completion 2/59.
# Extracting 20231213_081714_058_38_aplogcat.txt.zst with completion 3/59.
# Extracting 20231213_075204_113_21_aplogcat.txt.zst with completion 4/59.
# Extracting 20231213_084531_615_52_aplogcat.txt.zst with completion 5/59.
# Extracting 20231213_075814_119_25_aplogcat.txt.zst with completion 6/59.
# Extracting 20231213_085437_904_57_aplogcat.txt.zst with completion 7/59.
# Extracting 20231213_085648_087_58_aplogcat.txt.zst with completion 8/59.
# Extracting 20231213_074918_169_19_aplogcat.txt.zst with completion 9/59.
# Extracting 20231213_074158_239_14_aplogcat.txt.zst with completion 10/59.
# Extracting 20231213_083522_966_47_aplogcat.txt.zst with completion 11/59.
# Extracting 20231213_080414_122_29_aplogcat.txt.zst with completion 12/59.
# ...

# %%
output_file = os.path.join(log_path, "all_log.csv")
all_log.to_csv(output_file, encoding = "ISO-8859-1", index=None)

# %%
normal_log_path = os.path.join(current_dir, r"logs/srv_3dmodel_render")
extract_zst_files(normal_log_path, "logcat")
extract_zst_files(normal_log_path, "kernel")
all_log = merge_log_csv_files(normal_log_path)
output_file = os.path.join(normal_log_path, "all_log.csv")
all_log.to_csv(output_file, encoding = "ISO-8859-1", index=None)
# Out:
# Found 35 txt.zst files.
# Extracting 20231212_202125_360_31_aplogcat.txt.zst with completion 1/35.
# Extracting 20231212_200605_295_23_aplogcat.txt.zst with completion 2/35.
# Extracting 20231212_194457_444_11_aplogcat.txt.zst with completion 3/35.
# Extracting 20231212_200755_338_24_aplogcat.txt.zst with completion 4/35.
# Extracting 20231212_200415_302_22_aplogcat.txt.zst with completion 5/35.
# Extracting 20231212_201715_739_29_aplogcat.txt.zst with completion 6/35.
# Extracting 20231212_195327_463_16_aplogcat.txt.zst with completion 7/35.
# Extracting 20231212_134144_973_0_aplogcat.txt.zst with completion 8/35.
# Failed to extrat 20231212_134144_973_0_aplogcat.txt.zst, skipped.
# zstd decompress error: Unknown frame descriptor
# Extracting 20231212_193627_428_6_aplogcat.txt.zst with completion 9/35.
# Extracting 20231212_193117_932_3_aplogcat.txt.zst with completion 10/35.
# Extracting 20231212_200025_339_20_aplogcat.txt.zst with completion 11/35.
# ...
